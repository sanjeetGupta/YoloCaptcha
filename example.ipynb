# %%
import os
import random
import numpy as np
import pandas as pd
import solve_capcha
from create_model import build_yolo_model

# %%
model=build_yolo_model('weights.h5')

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 416, 416, 3)  0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 416, 416, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# norm_1 (BatchNormalization)     (None, 416, 416, 32) 128         conv_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 416, 416, 32) 0           norm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 208, 208, 32) 0           leaky_re_lu_1[0][0]
# ...

# %%
capcha_path='images/example1.png'
solve_capcha.solve_capcha(capcha_path,model,capcha_length=5,char_types=['upper','digit'],show_box=True,ot=0.3,nt=0.2)
# Out:
# g 0.33958974
# x 0.62409663
# 9 0.977428
# 9 0.8518812
# X 0.6916896
# l 0.32111993
# K 0.95033664
# (  char     score      xmin      xmax      ymin      ymax         x         y  \
#  2    9  0.977428  0.243800  0.418067  0.243800  0.418067  0.330933  0.330933
#  3    9  0.851881  0.840020  0.953652  0.840020  0.953652  0.896836  0.896836
#  4    X  0.691690  0.060913  0.215055  0.060913  0.215055  0.137984  0.137984
#  6    K  0.950337  0.634741  0.799000  0.634741  0.799000  0.716871  0.716871
#
#    char_type
#  2     digit
#  3     digit
#  4     upper
#  6     upper  , 'X9K9')

# %%
capcha_path='images/example2.png'
solve_capcha.solve_capcha(capcha_path,model,capcha_length=6,char_types=['upper','digit'])
# Out:
# /media/developer/e-drive/sanjeet/keras-yolo2/examples/capcha_model/solve_capcha.py:194: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   arg=df.x_dis.argmin()
# /media/developer/e-drive/sanjeet/keras-yolo2/examples/capcha_model/solve_capcha.py:195: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   drop_arg=df.iloc[arg:arg+2,:]['score'].argmin()
# (   char     score      xmin      xmax      ymin      ymax         x         y  \
#  4     2  0.137433  0.839938  0.962385  0.839938  0.962385  0.901162  0.901162
#  5     B  0.094977  0.829013  0.966143  0.829013  0.966143  0.897578  0.897578
# ...

# %%
capcha_path='images/example4.png'
plt.imshow(cv2.imread(capcha_path))
plt.show()
solve_capcha.solve_capcha(capcha_path,model,capcha_length=5,path=False,char_types=['upper','digit'],compress_function='dis',ot=0.1,nt=0.5)
# Out:
# /media/developer/e-drive/sanjeet/keras-yolo2/examples/capcha_model/solve_capcha.py:194: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   arg=df.x_dis.argmin()
# /media/developer/e-drive/sanjeet/keras-yolo2/examples/capcha_model/solve_capcha.py:195: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   drop_arg=df.iloc[arg:arg+2,:]['score'].argmin()
# (   char     score      xmin      xmax      ymin      ymax         x         y  \
#  3     L  0.899160 -0.019593  0.243026 -0.019593  0.243026  0.111716  0.111716
#  4     L  0.845269  0.079381  0.151228  0.079381  0.151228  0.115305  0.115305
# ...
